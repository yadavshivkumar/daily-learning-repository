# %% [markdown]
# Variable Initialization

# %%
x = 5
x = x+5

# %%
y = 30 
print(x)
print(y)
# Out:
# 10
# 30

# %%
from datetime import date
#this is a simple question related to the jupyter notebook.
