# %% [markdown]
# # My First Code

# %% [markdown]
# ## Hello World

# %%
x = "Hello world"
x
# Out:
# 'Hello world'

# %% [markdown]
# ## Hello Python

# %%
y = "Hello Python"
y
# Out:
# 'Hello Python'

# %% [markdown]
# # My Second Code

# %% [markdown]
# # Sum

# %%
a = 10
b = 7

# %%
print(a+b)
# Out:
# 17

# %% [markdown]
# # Diff

# %%
a-b
# Out:
# 3

# %%
# %%html
# <marquee style='width: 30%; color: blue;'><b>Shiv!</b></marquee>
# Out:
# <marquee style='width: 30%; color: blue;'><b>Shiv!</b></marquee>

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.1-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 7.5 MB/s  0:00:008.0 MB/s eta 0:00:01m
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !numpy --version
# Out:
# zsh:1: command not found: numpy

# %%
# !python3 --version
# Out:
# Python 3.14.2

# %%
# !pip install pytorch
# Out:
# Collecting pytorch
#   Downloading pytorch-1.0.2.tar.gz (689 bytes)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pytorch
#   Building wheel for pytorch (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pytorch (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [37 lines of output]
#       Traceback (most recent call last):
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 280, in build_wheel
#           return _build_backend().build_wheel(
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#               wheel_directory, config_settings, metadata_directory
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           )
#           ^
#         File "/private/var/folders/jt/n56w3tg91kg9l4hr43d1y6_m0000gn/T/pip-build-env-mgb7fym5/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 439, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#         File "/private/var/folders/jt/n56w3tg91kg9l4hr43d1y6_m0000gn/T/pip-build-env-mgb7fym5/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 427, in _build
#           return self._build_with_temp_dir(
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^
#               cmd,
#               ^^^^
#           ...<3 lines>...
#               self._arbitrary_args(config_settings),
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           )
#           ^
#         File "/private/var/folders/jt/n56w3tg91kg9l4hr43d1y6_m0000gn/T/pip-build-env-mgb7fym5/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 408, in _build_with_temp_dir
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/jt/n56w3tg91kg9l4hr43d1y6_m0000gn/T/pip-build-env-mgb7fym5/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 518, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/jt/n56w3tg91kg9l4hr43d1y6_m0000gn/T/pip-build-env-mgb7fym5/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 15, in <module>
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
# Failed to build pytorch
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> pytorch

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.4 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-25.3

# %%
pip --version
# Out:
# pip 25.3 from /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pip (python 3.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install git
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git

# %%
# !brew install git
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with `$HOMEBREW_AUTO_UPDATE_SECS` or disable with
# `$HOMEBREW_NO_AUTO_UPDATE=1`. Hide these hints with `$HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/core/portable-ruby/blobs/sha256:1c98fa49eacc935640a6f8e10a2bf33f14cfc276804b71ddb658ea45ba99d167
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.4.8.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# addlicense: Scan directories recursively to ensure source files have license headers
# adplay: Command-line player for OPL2 music
# aicommit2: Reactive CLI that generates commit messages for Git and Jujutsu with AI
# airtable-mcp-server: MCP Server for Airtable
# aklomp-base64: Fast Base64 stream encoder/decoder in C99, with SIMD acceleration
# anchor: Solana Program Framework
# ansible@12: Automate deployment, configuration, and upgrading
# any2fasta: Convert various sequence formats to FASTA
# archgw: CLI for Arch Gateway
# asm-lsp: Language server for NASM/GAS/GO Assembly
# astra: Command-Line Interface for DataStax Astra
# atomic_queue: C++14 lock-free queues
# attempt-cli: CLI for retrying fallible commands
# auto-editor: Effort free video editing!
# av1an: Cross-platform command-line encoding framework
# aws-spiffe-workload-helper: Helper for providing AWS credentials to workloads using their SPIFFE identity
# azure-dev: Developer CLI that provides commands for working with Azure resources
# azurite: Lightweight server clone of Azure Storage that simulates it locally
# beads: Memory upgrade for your coding agent
# beads_viewer: Terminal-based UI for the Beads issue tracker
# bedtk: Simple toolset for BED files
# bom: Utility to generate SPDX-compliant Bill of Materials manifests
# bookokrat: Terminal EPUB Book Reader
# btllib: Bioinformatics Technology Lab common code library
# bulletty: Pretty feed reader (ATOM/RSS) that stores articles in Markdown files
# bumpp: Interactive CLI that bumps your version numbers and more
# cagent: Agent Builder and Runtime by Docker Engineering
# calm-cli: CLI allows you to interact with the Common Architecture Language Model (CALM)
# carl: Calendar for the command-line
# ccextractor: Tool for extracting closed captions from video files
# cek: Explore the (overlay) filesystem and layers of OCI container images
# changelogen: Generate Beautiful Changelogs using Conventional Commits
# chrome-devtools-mcp: Chrome DevTools for coding agents
# cinecli: Browse, inspect, and launch movie torrents directly from your terminal
# classifier: Text classification with Bayesian, LSI, Logistic Regression, and kNN
# claude-cmd: Claude Code Commands Manager
# claude-code-router: Tool to route Claude Code requests to different models and customize any request
# claude-code-templates: CLI tool for configuring and monitoring Claude Code
# claude-hooks: Hook system for Claude Code
# clippy: Copy files from your terminal that actually paste into GUI apps
# cliproxyapi: Wrap Gemini CLI, Codex, Claude Code, Qwen Code as an API service
# codanna: Code intelligence system with semantic search
# codebook-lsp: Code-aware spell checker language server
# config-file-validator: CLI tool to validate different configuration file types
# container: Create and run Linux containers using lightweight virtual machines
# container-canary: Test and validate container requirements against versioned manifests
# container-compose: Manage Apple Container with Docker Compose files
# context7-mcp: Up-to-date code documentation for LLMs and AI code editors
# corepack: Package acting as bridge between Node projects and their package managers
# cpptrace: Simple, portable, and self-contained stacktrace library for C++11 and newer
# cronboard: Terminal-based dashboard for managing cron jobs locally and on servers
# ctags-lsp: LSP implementation using universal-ctags as backend
# ctre: Compile-time PCRE-compatible regular expression matcher for C++
# ctrld: Highly configurable, multi-protocol DNS forwarding proxy
# custom-install: Install CIA files directly to Nintendo 3DS SD card
# dash-mpd-cli: Download media content from a DASH-MPEG or DASH-WebM MPD manifest
# depot: Build your Docker images in the cloud
# devcockpit: TUI system monitor for Apple Silicon
# diffnav: Git diff pager based on delta but with a file tree
# dnote: Simple command-line notebook
# dnspyre: CLI tool for a high QPS DNS benchmark
# docker-compose-langserver: Language service for Docker Compose documents
# docker-language-server: Language server for Dockerfiles, Compose files, and Bake files
# docmd: Minimal Markdown documentation generator
# doge: Command-line DNS client
# doh: Stand-alone DNS-over-HTTPS resolver using libcurl
# dotnet@9: .NET Core
# dovi_convert: Dolby Vision Profile 7 to 8.1 MKV converter
# dqlite: Embeddable, replicated and fault-tolerant SQLite-powered engine
# dstp: Run common networking tests against your site
# durdraw: Versatile ASCII and ANSI Art text editor for drawing in the terminal
# e1s: TUI for managing AWS ECS, inspired by k9s
# eigen@3: C++ template library for linear algebra
# ekphos: Terminal-based markdown research tool inspired by Obsidian
# erlang-language-platform: LSP server and CLI for the Erlang programming language
# fake-gcs-server: Emulator for Google Cloud Storage API
# faketty: Wrapper to exec a command in a pty, even if redirecting the output
# fastmcp: Fast, Pythonic way to build MCP servers and clients
# fastrace: Dependency-free traceroute implementation in pure C
# fence: Lightweight sandbox for commands with network and filesystem restrictions
# fennel-ls: Language Server for Fennel
# fernflower: Advanced decompiler for Java bytecode
# ffmpeg-full: Play, record, convert, and stream many audio and video codecs
# filebrowser: Web File Browser
# fjira: Fuzzy-find cli jira interface
# flecs: Fast entity component system for C & C++
# fnox: Fort Knox for your secrets - flexible secret management tool
# forgejo-cli: CLI tool for interacting with Forgejo
# framework-tool-tui: TUI for controlling and monitoring Framework Computers hardware
# fresh-editor: Text editor for your terminal: easy, powerful and fast
# fzf-tab: Replace zsh completion selection menu with fzf
# garage: S3 object store so reliable you can run it outside datacenters
# gastown: Multi-agent workspace manager
# gcl: GNU Common Lisp
# getparty: Multi-part HTTP download manager
# ghc@9.12: Glorious Glasgow Haskell Compilation System
# ghidra: Multi-platform software reverse engineering framework
# git-get: Better way to clone, organize and manage multiple git repositories
# git-pages: Scalable static site server for Git forges
# git-pages-cli: Tool for publishing a site to a git-pages server
# git-xet: Git LFS plugin that uploads and downloads using the Xet protocol
# gitingest: Turn any Git repository into a prompt-friendly text ingest for LLMs
# gitlab-ci-linter: Command-line tool to lint GitLab CI YAML files
# gitlogue: Cinematic Git commit replay tool
# gitnr: Create `.gitignore` using templates from TopTal, GitHub or your own collection
# global-arrays: Partitioned Global Address Space (PGAS) library for distributed arrays
# gnuastro: Astronomical data manipulation and analysis utilities and libraries
# goat: General purpose AT Protocol CLI in Go
# gocheat: TUI Cheatsheet for keybindings, hotkeys and more
# goclone: Website Cloner
# gogcli: Google Suite CLI
# gotun: Lightweight HTTP proxy over SSH
# gphotos-uploader-cli: Command-line tool to mass upload media folders to Google Photos
# granted: Easiest way to access your cloud
# graphqlite: SQLite graph database extension
# gruyere: TUI program for viewing and killing processes listening on ports
# gtl: Greg's Template Library of useful classes
# gup: Update binaries installed by go install
# gwctl: CLI for managing and inspecting Gateway API resources in Kubernetes clusters
# hack-browser-data: Command-line tool for decrypting and exporting browser data
# hapless: Run and manage background processes
# haraka: Fast, highly extensible, and event driven SMTP server
# harbor-cli: CLI for Harbor container registry
# hayagriva: Bibliography management tool
# hdrhistogram_c: C port of the HdrHistogram
# headscale-cli: CLI for headscale, an open-source implementation of the Tailscale control server
# headson: Head/tail for structured data
# helix-db: Open-source graph-vector database built from scratch in Rust
# helm@3: Kubernetes package manager
# hexhog: Hex viewer/editor
# hf-mcp-server: MCP Server for Hugging Face
# hindent: Haskell pretty printer
# html-to-markdown: Transforms HTML (even entire websites) into clean, readable Markdown
# httptap: HTTP request visualizer with phase-by-phase timing breakdown
# icu4c@78: C/C++ and Java libraries for Unicode and globalization
# igrep: Interactive grep
# imagemagick-full: Tools and libraries to manipulate images in many formats
# install-nothing: Simulates installing things but doesn't actually install anything
# intelli-shell: Like IntelliSense, but for shells
# jiratui: Textual User Interface for interacting with Atlassian Jira from your shell
# joyce: Emulates the Amstrad PCW on Unix, Windows and macOS
# jqp: TUI playground to experiment and play with jq
# jsonfmt: Like gofmt, but for JSON files
# kagent: Kubernetes native framework for building AI agents
# kanata-tray: System tray for kanata keyboard remapper
# karakeep: CLI tool for self-hostable bookmark-everything app karakeep
# kekkai: File integrity monitoring tool
# khaos: Kafka traffic simulator for observability and chaos engineering
# kibi: Text editor in ≤1024 lines of code, written in Rust
# kimi-cli: CLI agent for MoonshotAI Kimi platform
# klog: Command-line tool for time tracking in a human-readable, plain-text file format
# komac: Community Manifest Creator for Windows Package Manager (WinGet)
# krane: Kubernetes deploy tool with rollout verification
# ktea: Kafka TUI client
# kubefwd: Bulk port forwarding Kubernetes services for local development
# kubernetes-cli@1.33: Kubernetes command-line interface
# kubernetes-cli@1.34: Kubernetes command-line interface
# kyua: Testing framework for infrastructure software
# labctl: CLI tool for interacting with iximiuz labs and playgrounds
# ladybug: Embedded graph database built for query speed and scalability
# lazycontainer: Terminal UI for Apple Containers
# lazyssh: Terminal-based SSH manager
# leetsolv: CLI tool for DSA problem revision with spaced repetition
# libaegis: Portable C implementations of the AEGIS family of encryption algorithms
# libcpucycles: Microlibrary for counting CPU cycles
# libdecor: Client-side decorations library for Wayland client
# libevdev: Wrapper library for evdev devices
# libigloo: Generic C framework used and developed by the Icecast project
# libks: Foundational support for signalwire C products
# libpq@17: Postgres C API library
# libptytty: Library for OS-independent pseudo-TTY management
# libselinux: SELinux library and simple utilities
# libsepol: SELinux binary policy manipulation library
# libthai: Thai language support library
# lispkit: Scheme framework for extension and scripting languages on macOS and iOS
# litehtml: Fast and lightweight HTML/CSS rendering engine
# llhttp: Port of http_parser to llparse
# lue-reader: Terminal eBook reader with text-to-speech and multi-format support
# macchanger: Change your mac address, for macOS
# magics: ECMWF's meteorological plotting software
# magika: Fast and accurate AI powered file content types detection
# maigret: Collect a dossier on a person by username from thousands of sites
# mail-deduplicate: CLI to deduplicate mails from mail boxes
# mapscii: Whole World In Your Console
# mariadb@11.8: Drop-in replacement for MySQL
# mark: Sync your markdown files with Confluence pages
# matcha: Daily digest generator for your RSS feeds
# mbedtls@3: Cryptographic & SSL/TLS library
# mcat: Terminal image, video, directory, and Markdown viewer
# mcp-atlassian: MCP server for Atlassian tools (Confluence, Jira)
# mcp-google-sheets: MCP server integrates with your Google Drive and Google Sheets
# mcp-grafana: MCP server for Grafana
# mcp-publisher: Publisher CLI tool for the Official Model Context Protocol (MCP) Registry
# mcp-scan: Constrain, log and scan your MCP connections for security vulnerabilities
# mcp-server-chart: MCP with 25+ @antvis charts for visualization, generation, and analysis
# mcp-server-kubernetes: MCP Server for kubernetes management commands
# mdfried: Terminal markdown viewer
# mdserve: Fast markdown preview server with live reload and theme support
# minizign: Minisign reimplemented in Zig
# mistral-vibe: Minimal CLI coding agent
# mitama-cpp-result: Provides `result<T, E>` and `maybe<T>` and monadic functions for them
# mlx-c: C API for MLX
# mlx-lm: Run LLMs with MLX
# mole: Deep clean and optimize your Mac
# moribito: TUI for LDAP Viewing/Queries
# mq: Jq-like command-line tool for markdown processing
# msedit: Simple text editor with clickable interface
# mufetch: Neofetch-style music cli
# mysql-to-sqlite3: Transfer data from MySQL to SQLite
# n8n-mcp: MCP for Claude Desktop, Claude Code, Windsurf, Cursor to build n8n workflows
# nanobot: Build MCP Agents
# nativefiledialog-extended: Native file dialog library with C and C++ bindings
# neo4j-mcp: Neo4j official Model Context Protocol server for AI tools
# netshow: Interactive network connection monitor with friendly service names
# nextflow: Reproducible scientific workflows
# ni: Selects the right Node package manager based on lockfiles
# nkt: TUI for fast and simple interacting with your BibLaTeX database
# node@24: Open-source, cross-platform JavaScript runtime environment
# oatpp: Light and powerful C++ web framework
# octodns: Tools for managing DNS across multiple providers
# openapv: Open Advanced Professional Video Codec
# openblas64: Optimized BLAS library
# opencode: AI coding agent, built for the terminal
# openlist: New AList fork addressing anti-trust issues
# openskills: Universal skills loader for AI coding agents
# openssl@3.5: Cryptography and SSL/TLS Toolkit
# oxfmt: High-performance formatting tool for JavaScript and TypeScript
# pake: Turn any webpage into a desktop app with Rust with ease
# papeer: Convert websites into eBooks and Markdown
# papis: Powerful command-line document and bibliography manager
# parqeye: Peek inside Parquet files right from your terminal
# patchpal: AI Assisted Patch Backporting Tool Frontend
# pelican: Static site generator that supports Markdown and reST syntax
# permify: Open-source authorization service & policy engine based on Google Zanzibar
# pgroll: Postgres zero-downtime migrations made easy
# pgstream: PostgreSQL replication with DDL changes
# phantom: CLI tool for seamless parallel development with Git worktrees
# php@8.4: General-purpose scripting language
# pipewire: Server and user space API to deal with multimedia pipelines
# pixlet: App runtime and UX toolkit for pixel-based apps
# playwright-mcp: MCP server for Playwright
# pocket-tts: Text-to-speech application designed to run efficiently on CPUs
# pony-language-server: Language server for Pony
# portable-libffi: Portable Foreign Function Interface library
# portable-libxcrypt: Extended crypt library for descrypt, md5crypt, bcrypt, and others
# portable-libyaml: YAML Parser
# portable-openssl: Cryptography and SSL/TLS Toolkit
# portable-ruby: Powerful, clean, object-oriented scripting language
# portable-zlib: General-purpose lossless data-compression library
# postgres-language-server: Language Server for Postgres
# postgresql@18: Object-relational database system
# precice: Coupling library for partitioned multi-physics simulations
# privatebin-cli: CLI for creating and managing PrivateBin pastes
# pvetui: Terminal UI for Proxmox VE
# py7zr: 7-zip in Python
# pyscn: Intelligent Python Code Quality Analyzer
# python-gdbm@3.14: Python interface to gdbm
# python-tk@3.14: Python interface to Tcl/Tk
# python@3.14: Interpreted, interactive, object-oriented programming language
# q: Tiny command-line DNS client with support for UDP, TCP, DoT, DoH, DoQ and ODoH
# qcoro6: C++ Coroutines for Qt
# qo: Interactive minimalist TUI to query JSON, CSV, and TSV using SQL
# qqqa: Fast, stateless LLM for your shell: qq answers; qa runs commands
# qt3d: Provides functionality for near-realtime simulation systems
# qt5compat: Qt 5 Core APIs that were removed in Qt 6
# qtbase: Cross-platform application and UI framework
# qtcharts: UI Components for displaying visually pleasing charts
# qtconnectivity: Provides access to Bluetooth hardware
# qtdatavis3d: Provides functionality for 3D visualization
# qtdeclarative: QML, Qt Quick and several related modules
# qtgraphs: Provides functionality for 2D and 3D graphs
# qtgrpc: Provides support for communicating with gRPC services
# qthttpserver: Framework for embedding an HTTP server into a Qt application
# qtimageformats: Plugins for additional image formats: TIFF, MNG, TGA, WBMP
# qtlanguageserver: Implementation of the Language Server Protocol and JSON-RPC
# qtlocation: Provides C++ interfaces to retrieve location and navigational information
# qtlottie: Display graphics and animations exported by the Bodymovin plugin
# qtmultimedia: Provides APIs for playing back and recording audiovisual content
# qtnetworkauth: Provides support for OAuth-based authorization to online services
# qtpositioning: Provides access to position, satellite info and area monitoring classes
# qtquick3d: Provides a high-level API for creating 3D content or UIs based on Qt Quick
# qtquick3dphysics: High-level QML module adding physical simulation capabilities to Qt Quick 3D
# qtquickeffectmaker: Tool to create custom Qt Quick shader effects
# qtquicktimeline: Enables keyframe-based animations and parameterization
# qtremoteobjects: Provides APIs for inter-process communication
# qtscxml: Provides functionality to create state machines from SCXML files
# qtsensors: Provides access to sensors via QML and C++ interfaces
# qtserialbus: Provides access to serial industrial bus interfaces
# qtserialport: Provides classes to interact with hardware and virtual serial ports
# qtshadertools: Provides tools for the cross-platform Qt shader pipeline
# qtspeech: Enables access to text-to-speech engines
# qtsvg: Classes for displaying the contents of SVG files
# qttools: Facilitate the design, development, testing and deployment of applications
# qttranslations: Qt translation catalogs
# qtvirtualkeyboard: Provides an input framework and reference keyboard frontend
# qtwayland: Wayland platform plugin and QtWaylandCompositor API
# qtwebchannel: Bridges the gap between Qt applications and HTML/JavaScript
# qtwebengine: Provides functionality for rendering regions of dynamic web content
# qtwebsockets: Provides WebSocket communication compliant with RFC 6455
# qtwebview: Displays web content in a QML application
# quint: Core tool for the Quint specification language
# rad: Modern CLI scripts made easy
# radicle: Sovereign code forge built on Git
# radvd: IPv6 Router Advertisement Daemon
# rails-mcp-server: MCP server for Rails applications
# ralph-orchestrator: Multi-agent orchestration framework for autonomous AI task completion
# recur: Retry a command with exponential backoff and jitter
# reddix: Reddit, refined for the terminal
# redis@8.2: Persistent key-value database, with built-in net interface
# redu: Ncdu for your restic repository
# repeater: Flashcard program that uses spaced repetition
# resterm: Terminal client for .http/.rest files with HTTP, GraphQL, and gRPC support
# rig-r: R Installation Manager
# rmrfrs: Filesystem cleaning tool
# rockcraft: Tool to create OCI images using the language from Snapcraft and Charmcraft
# rolesanywhere-credential-helper: Manages getting temporary security credentials from IAM Roles Anywhere
# ruby@3.4: Powerful, clean, object-oriented scripting language
# rumdl: Markdown Linter and Formatter written in Rust
# rv-r: Declarative R package manager
# salesforce-mcp: MCP Server for interacting with Salesforce instances
# sandvault: Run AI agents isolated in a sandboxed macOS user account
# sarif-tools: Set of command-line tools and Python library for working with SARIF files
# save3ds_fuse: Extract/Import/FUSE for 3DS save/extdata/database
# seqan3: Modern C++ library for sequence analysis
# shiki: Beautiful yet powerful syntax highlighter
# shimmy: Small local inference server with OpenAI-compatible GGUF endpoints
# shortest: AI-powered natural language end-to-end testing framework
# signalwire-client-c: SignalWire C Client SDK
# slack-mcp-server: Powerful MCP Slack Server with multiple transports and smart history fetch logic
# slicot: Fortran subroutines library for systems and control
# snitch: Prettier way to inspect network connections
# snooze: Run a command at a particular time
# specify: Toolkit to help you get started with Spec-Driven Development
# spiffe-helper: Tool that can be used to retrieve and manage SVIDs on behalf of a workload
# sqlite3-to-mysql: Transfer data from SQLite to MySQL
# strands-agents-sops: Standard Operating Procedures for AI agents using natural language
# supabase: Open source Firebase alternative
# superseedr: BitTorrent Client in your Terminal
# svt-vp9: Scalable Video Technology for VP9 Encoder
# svu: Semantic version utility
# swag: Automatically generate RESTful API documentation with Swagger 2.0 for Go
# talm: Manage Talos Linux configurations the GitOps way
# taskline: Tasks, boards & notes for the command-line habitat
# taze: Modern cli tool that keeps your deps fresh
# teamtype: Peer-to-peer, editor-agnostic collaborative editing of local text files
# termshot: Creates screenshots based on terminal command output
# termsvg: Record, share and export your terminal as a animated SVG image
# terratag: CLI to automate tagging for AWS, Azure & GCP resources in Terraform
# tfclean: Remove applied moved block, import block, etc
# tfplugingen-openapi: OpenAPI to Terraform Provider Code Generation Specification
# tfstate-lookup: Lookup resource attributes in tfstate
# tftp-now: Single-binary TFTP server and client that you can use right now
# thorvg: Lightweight portable library used for drawing vector-based scenes and animations
# tkrzw: Set of implementations of DBM
# tock: Powerful time tracking tool for the command-line
# toktop: LLM usage monitor in terminal
# tombi: TOML formatter, linter and language server
# topydo: Todo list application using the todo.txt format
# torrra: Find and download torrents without leaving your CLI
# tracetest: Build integration and end-to-end tests
# tree-sitter@0.25: Incremental parsing library
# treemd: TUI and CLI dual pane markdown viewer
# tronbyt-server: Manage your apps on your Tronbyt (flashed Tidbyt) completely locally
# ts_query_ls: LSP implementation for Tree-sitter's query files
# tscriptify: Golang struct to TypeScript class/interface converter
# tuios: Terminal UI OS (Terminal Multiplexer)
# tweakcc: Customize your Claude Code themes, thinking verbs, and more
# ty: Extremely fast Python type checker, written in Rust
# vacuum: World's fastest OpenAPI & Swagger linter
# vampire: High-performance theorem prover
# vgo: Project scaffolder for Go, written in Go
# vibe-log-cli: CLI tool for analyzing Claude Code sessions
# vibecheck: AI-powered git commit assistant written in Go
# volcano-cli: CLI for Volcano, Cloud Native Batch System
# vtcode: CLI Semantic Coding Agent
# vtsls: LSP wrapper for typescript extension of vscode
# wal-g: Archival restoration tool for databases
# wasm-bindgen: Facilitating high-level interactions between Wasm modules and JavaScript
# wassette: Security-oriented runtime that runs WebAssembly Components via MCP
# whosthere: LAN discovery tool with a modern TUI written in Go
# wifitui: Fast featureful friendly wifi terminal UI
# wik: View Wikipedia pages from your terminal
# witr: Why is this running?
# worktrunk: CLI for Git worktree management, designed for parallel AI agent workflows
# wuchale: Protobuf-like i18n from plain code
# wuppiefuzz: Coverage-guided REST API fuzzer developed on top of LibAFL
# xcp: Fast & lightweight command-line tool for managing Xcode projects, built in Swift
# xcsift: Swift tool to parse xcodebuild output for coding agents
# xleak: Terminal Excel viewer with an interactive TUI
# yamlresume: Resumes as code in YAML
# yuque-dl: Knowledge base downloader for Yuque
# zsv: Tabular data swiss-army knife CLI
# zuban: Python language server and type checker, written in Rust
#
# You have 7 outdated formulae installed.
#
# git 2.50.1 is already installed but outdated (so it will be upgraded).
# ==> Fetching downloads for: git
# ⠋ Bottle Manifest git (2.52.0_1)⠋ Bottle Manifest git (2.52.0_1)⠙ Bottle Manifest git (2.52.0_1)⠙ Bottle Manifest git (2.52.0_1)⠚ Bottle Manifest git (2.52.0_1)⠚ Bottle Manifest git (2.52.0_1)⠞ Bottle Manifest git (2.52.0_1)⠞ Bottle Manifest git (2.52.0_1)⠖ Bottle Manifest git (2.52.0_1)⠖ Bottle Manifest git (2.52.0_1)                     Downloading  12.3KB/-------✔︎ Bottle Manifest git (2.52.0_1)                     Downloaded   20.9KB/ 20.9KB
# ⠦ Bottle Manifest libunistring (1.4.1)
# ⠦ Bottle libunistring (1.4.1)
# ⠦ Bottle Manifest gettext (0.26_1)
# ⠦ Bottle gettext (0.26_1)
# ⠦ Bottle Manifest pcre2 (10.47)
# ⠦ Bottle pcre2 (10.47)
# ⠦ Bottle Manifest libiconv (1.18)
# ⠦ Bottle libiconv (1.18)
# ⠦ Bottle git (2.52.0_1)⠦ Bottle Manifest libunistring (1.4.1)
# ⠦ Bottle libunistring (1.4.1)
# ⠦ Bottle Manifest gettext (0.26_1)
# ⠦ Bottle gettext (0.26_1)
# ⠦ Bottle Manifest pcre2 (10.47)
# ⠦ Bottle pcre2 (10.47)
# ⠦ Bottle Manifest libiconv (1.18)
# ⠦ Bottle libiconv (1.18)
# ⠦ Bottle git (2.52.0_1)⠴ Bottle Manifest libunistring (1.4.1)
# ⠴ Bottle libunistring (1.4.1)
# ⠴ Bottle Manifest gettext (0.26_1)
# ⠴ Bottle gettext (0.26_1)
# ⠴ Bottle Manifest pcre2 (10.47)
# ⠴ Bottle pcre2 (10.47)
# ⠴ Bottle Manifest libiconv (1.18)
# ⠴ Bottle libiconv (1.18)
# ⠴ Bottle git (2.52.0_1)⠴ Bottle Manifest libunistring (1.4.1)
# ⠴ Bottle libunistring (1.4.1)
# ⠴ Bottle Manifest gettext (0.26_1)
# ⠴ Bottle gettext (0.26_1)
# ⠴ Bottle Manifest pcre2 (10.47)
# ⠴ Bottle pcre2 (10.47)
# ⠴ Bottle Manifest libiconv (1.18)
# ⠴ Bottle libiconv (1.18)
# ⠴ Bottle git (2.52.0_1)⠲ Bottle Manifest libunistring (1.4.1)
# ⠲ Bottle libunistring (1.4.1)
# ⠲ Bottle Manifest gettext (0.26_1)
# ⠲ Bottle gettext (0.26_1)
# ⠲ Bottle Manifest pcre2 (10.47)
# ⠲ Bottle pcre2 (10.47)
# ⠲ Bottle Manifest libiconv (1.18)
# ⠲ Bottle libiconv (1.18)
# ⠲ Bottle git (2.52.0_1)⠲ Bottle Manifest libunistring (1.4.1)
# ⠲ Bottle libunistring (1.4.1)
# ⠲ Bottle Manifest gettext (0.26_1)
# ⠲ Bottle gettext (0.26_1)
# ⠲ Bottle Manifest pcre2 (10.47)
# ⠲ Bottle pcre2 (10.47)
# ⠲ Bottle Manifest libiconv (1.18)
# ⠲ Bottle libiconv (1.18)
# ⠲ Bottle git (2.52.0_1)⠳ Bottle Manifest libunistring (1.4.1)
# ⠳ Bottle libunistring (1.4.1)
# ⠳ Bottle Manifest gettext (0.26_1)
# ⠳ Bottle gettext (0.26_1)
# ⠳ Bottle Manifest pcre2 (10.47)
# ⠳ Bottle pcre2 (10.47)
# ⠳ Bottle Manifest libiconv (1.18)
# ⠳ Bottle libiconv (1.18)
# ⠳ Bottle git (2.52.0_1)⠳ Bottle Manifest libunistring (1.4.1)
# ⠳ Bottle libunistring (1.4.1)
# ⠳ Bottle Manifest gettext (0.26_1)
# ⠳ Bottle gettext (0.26_1)
# ⠳ Bottle Manifest pcre2 (10.47)
# ⠳ Bottle pcre2 (10.47)
# ⠳ Bottle Manifest libiconv (1.18)
# ⠳ Bottle libiconv (1.18)
# ⠳ Bottle git (2.52.0_1)⠓ Bottle Manifest libunistring (1.4.1)
# ⠓ Bottle libunistring (1.4.1)
# ⠓ Bottle Manifest gettext (0.26_1)
# ⠓ Bottle gettext (0.26_1)
# ⠓ Bottle Manifest pcre2 (10.47)
# ⠓ Bottle pcre2 (10.47)
# ⠓ Bottle Manifest libiconv (1.18)
# ⠓ Bottle libiconv (1.18)
# ⠓ Bottle git (2.52.0_1)✔︎ Bottle Manifest libunistring (1.4.1)               Downloaded    7.3KB/  7.3KB
# ✔︎ Bottle Manifest gettext (0.26_1)                   Downloaded   13.8KB/ 13.8KB
# ✔︎ Bottle Manifest pcre2 (10.47)                      Downloaded   10.4KB/ 10.4KB
# ⠓ Bottle libunistring (1.4.1)
# ⠓ Bottle gettext (0.26_1)
# ⠓ Bottle pcre2 (10.47)
# ⠓ Bottle Manifest libiconv (1.18)
# ⠓ Bottle libiconv (1.18)
# ⠓ Bottle git (2.52.0_1)✔︎ Bottle Manifest libiconv (1.18)                    Downloaded    7.5KB/  7.5KB
# ⠋ Bottle libunistring (1.4.1)                        Downloading  45.1KB/  1.9MB
# ⠋ Bottle gettext (0.26_1)                            Downloading  28.7KB/  9.6MB
# ⠋ Bottle pcre2 (10.47)
# ⠋ Bottle libiconv (1.18)
# ⠋ Bottle git (2.52.0_1)⠋ Bottle libunistring (1.4.1)          #             Downloading 127.0KB/  1.9MB
# ⠋ Bottle gettext (0.26_1)                            Downloading  94.2KB/  9.6MB
# ⠋ Bottle pcre2 (10.47)                               Downloading  61.4KB/  2.4MB
# ⠋ Bottle libiconv (1.18)
# ⠋ Bottle git (2.52.0_1)⠙ Bottle libunistring (1.4.1)          ##            Downloading 274.4KB/  1.9MB
# ⠙ Bottle gettext (0.26_1)                            Downloading 241.7KB/  9.6MB
# ⠙ Bottle pcre2 (10.47)                 #             Downloading 159.7KB/  2.4MB
# ⠙ Bottle libiconv (1.18)                             Downloading  32.8KB/  1.6MB
# ⠙ Bottle git (2.52.0_1)⠙ Bottle libunistring (1.4.1)          ##            Downloading 356.4KB/  1.9MB
# ⠙ Bottle gettext (0.26_1)                            Downloading 356.4KB/  9.6MB
# ⠙ Bottle pcre2 (10.47)                 #             Downloading 258.0KB/  2.4MB
# ⠙ Bottle libiconv (1.18)                             Downloading  57.3KB/  1.6MB
# ⠙ Bottle git (2.52.0_1)                              Downloading  28.7KB/ 21.5MB⠚ Bottle libunistring (1.4.1)          ###           Downloading 454.7KB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              #             Downloading 651.3KB/  9.6MB
# ⠚ Bottle pcre2 (10.47)                 ###           Downloading 520.2KB/  2.4MB
# ⠚ Bottle libiconv (1.18)               #             Downloading 114.7KB/  1.6MB
# ⠚ Bottle git (2.52.0_1)                              Downloading  45.1KB/ 21.5MB⠚ Bottle libunistring (1.4.1)          ####          Downloading 634.9KB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              ##            Downloading   1.3MB/  9.6MB
# ⠚ Bottle pcre2 (10.47)                 ####          Downloading 806.9KB/  2.4MB
# ⠚ Bottle libiconv (1.18)               ##            Downloading 262.1KB/  1.6MB
# ⠚ Bottle git (2.52.0_1)                              Downloading 127.0KB/ 21.5MB⠞ Bottle libunistring (1.4.1)          ####          Downloading 634.9KB/  1.9MB
# ⠞ Bottle gettext (0.26_1)              ##            Downloading   1.3MB/  9.6MB
# ⠞ Bottle pcre2 (10.47)                 #######       Downloading   1.3MB/  2.4MB
# ⠞ Bottle libiconv (1.18)               ###           Downloading 340.0KB/  1.6MB
# ⠞ Bottle git (2.52.0_1)                              Downloading 143.4KB/ 21.5MB⠞ Bottle libunistring (1.4.1)          ####          Downloading 634.9KB/  1.9MB
# ⠞ Bottle gettext (0.26_1)              ##            Downloading   1.6MB/  9.6MB
# ⠞ Bottle pcre2 (10.47)                 #######       Downloading   1.3MB/  2.4MB
# ⠞ Bottle libiconv (1.18)               ###           Downloading 340.0KB/  1.6MB
# ⠞ Bottle git (2.52.0_1)                              Downloading 143.4KB/ 21.5MB⠖ Bottle libunistring (1.4.1)          #####         Downloading 749.6KB/  1.9MB
# ⠖ Bottle gettext (0.26_1)              ###           Downloading   1.9MB/  9.6MB
# ⠖ Bottle pcre2 (10.47)                 #######       Downloading   1.4MB/  2.4MB
# ⠖ Bottle libiconv (1.18)               ###           Downloading 356.4KB/  1.6MB
# ⠖ Bottle git (2.52.0_1)                              Downloading 225.3KB/ 21.5MB⠖ Bottle libunistring (1.4.1)          #####         Downloading 766.0KB/  1.9MB
# ⠖ Bottle gettext (0.26_1)              ###           Downloading   2.2MB/  9.6MB
# ⠖ Bottle pcre2 (10.47)                 #######       Downloading   1.4MB/  2.4MB
# ⠖ Bottle libiconv (1.18)               ###           Downloading 389.1KB/  1.6MB
# ⠖ Bottle git (2.52.0_1)                              Downloading 241.7KB/ 21.5MB⠦ Bottle libunistring (1.4.1)          ######        Downloading 798.7KB/  1.9MB
# ⠦ Bottle gettext (0.26_1)              ###           Downloading   2.2MB/  9.6MB
# ⠦ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠦ Bottle libiconv (1.18)               ###           Downloading 405.5KB/  1.6MB
# ⠦ Bottle git (2.52.0_1)                              Downloading 323.6KB/ 21.5MB⠦ Bottle libunistring (1.4.1)          ######        Downloading 815.1KB/  1.9MB
# ⠦ Bottle gettext (0.26_1)              ###           Downloading   2.3MB/  9.6MB
# ⠦ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠦ Bottle libiconv (1.18)               ###           Downloading 405.5KB/  1.6MB
# ⠦ Bottle git (2.52.0_1)                              Downloading 340.0KB/ 21.5MB⠴ Bottle libunistring (1.4.1)          ######        Downloading 815.1KB/  1.9MB
# ⠴ Bottle gettext (0.26_1)              ###           Downloading   2.3MB/  9.6MB
# ⠴ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠴ Bottle libiconv (1.18)               ###           Downloading 405.5KB/  1.6MB
# ⠴ Bottle git (2.52.0_1)                              Downloading 340.0KB/ 21.5MB⠴ Bottle libunistring (1.4.1)          ######        Downloading 815.1KB/  1.9MB
# ⠴ Bottle gettext (0.26_1)              ###           Downloading   2.3MB/  9.6MB
# ⠴ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠴ Bottle libiconv (1.18)               ###           Downloading 405.5KB/  1.6MB
# ⠴ Bottle git (2.52.0_1)                              Downloading 340.0KB/ 21.5MB⠲ Bottle libunistring (1.4.1)          ######        Downloading 815.1KB/  1.9MB
# ⠲ Bottle gettext (0.26_1)              ###           Downloading   2.3MB/  9.6MB
# ⠲ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠲ Bottle libiconv (1.18)               ###           Downloading 405.5KB/  1.6MB
# ⠲ Bottle git (2.52.0_1)                              Downloading 340.0KB/ 21.5MB⠲ Bottle libunistring (1.4.1)          ######        Downloading 831.5KB/  1.9MB
# ⠲ Bottle gettext (0.26_1)              ###           Downloading   2.3MB/  9.6MB
# ⠲ Bottle pcre2 (10.47)                 ########      Downloading   1.5MB/  2.4MB
# ⠲ Bottle libiconv (1.18)               ###           Downloading 438.3KB/  1.6MB
# ⠲ Bottle git (2.52.0_1)                              Downloading 356.4KB/ 21.5MB⠳ Bottle libunistring (1.4.1)          ######        Downloading 847.9KB/  1.9MB
# ⠳ Bottle gettext (0.26_1)              ###           Downloading   2.4MB/  9.6MB
# ⠳ Bottle pcre2 (10.47)                 #########     Downloading   1.6MB/  2.4MB
# ⠳ Bottle libiconv (1.18)               ####          Downloading 487.4KB/  1.6MB
# ⠳ Bottle git (2.52.0_1)                              Downloading 405.5KB/ 21.5MB⠳ Bottle libunistring (1.4.1)          ######        Downloading 864.3KB/  1.9MB
# ⠳ Bottle gettext (0.26_1)              ####          Downloading   2.6MB/  9.6MB
# ⠳ Bottle pcre2 (10.47)                 #########     Downloading   1.8MB/  2.4MB
# ⠳ Bottle libiconv (1.18)               ####          Downloading 520.2KB/  1.6MB
# ⠳ Bottle git (2.52.0_1)                              Downloading 471.0KB/ 21.5MB⠓ Bottle libunistring (1.4.1)          #######       Downloading   1.0MB/  1.9MB
# ⠓ Bottle gettext (0.26_1)              ####          Downloading   2.8MB/  9.6MB
# ⠓ Bottle pcre2 (10.47)                 ##########    Downloading   1.9MB/  2.4MB
# ⠓ Bottle libiconv (1.18)               ####          Downloading 569.3KB/  1.6MB
# ⠓ Bottle git (2.52.0_1)                              Downloading 585.7KB/ 21.5MB⠓ Bottle libunistring (1.4.1)          #######       Downloading   1.0MB/  1.9MB
# ⠓ Bottle gettext (0.26_1)              ####          Downloading   2.8MB/  9.6MB
# ⠓ Bottle pcre2 (10.47)                 ###########   Downloading   2.0MB/  2.4MB
# ⠓ Bottle libiconv (1.18)               #####         Downloading 602.1KB/  1.6MB
# ⠓ Bottle git (2.52.0_1)                              Downloading 634.9KB/ 21.5MB⠋ Bottle libunistring (1.4.1)          ########      Downloading   1.2MB/  1.9MB
# ⠋ Bottle gettext (0.26_1)              ####          Downloading   3.0MB/  9.6MB
# ⠋ Bottle pcre2 (10.47)                 ###########   Downloading   2.1MB/  2.4MB
# ⠋ Bottle libiconv (1.18)               ######        Downloading 782.3KB/  1.6MB
# ⠋ Bottle git (2.52.0_1)                              Downloading 749.6KB/ 21.5MB⠋ Bottle libunistring (1.4.1)          ########      Downloading   1.2MB/  1.9MB
# ⠋ Bottle gettext (0.26_1)              ####          Downloading   3.2MB/  9.6MB
# ⠋ Bottle pcre2 (10.47)                 ###########   Downloading   2.2MB/  2.4MB
# ⠋ Bottle libiconv (1.18)               #######       Downloading 880.6KB/  1.6MB
# ⠋ Bottle git (2.52.0_1)                              Downloading 782.3KB/ 21.5MB⠙ Bottle libunistring (1.4.1)          ########      Downloading   1.2MB/  1.9MB
# ⠙ Bottle gettext (0.26_1)              ####          Downloading   3.2MB/  9.6MB
# ⠙ Bottle pcre2 (10.47)                 ############  Downloading   2.2MB/  2.4MB
# ⠙ Bottle libiconv (1.18)               #######       Downloading 880.6KB/  1.6MB
# ⠙ Bottle git (2.52.0_1)                              Downloading 798.7KB/ 21.5MB⠙ Bottle libunistring (1.4.1)          #########     Downloading   1.2MB/  1.9MB
# ⠙ Bottle gettext (0.26_1)              ####          Downloading   3.3MB/  9.6MB
# ⠙ Bottle pcre2 (10.47)                 ############  Downloading   2.2MB/  2.4MB
# ⠙ Bottle libiconv (1.18)               ########      Downloading   1.0MB/  1.6MB
# ⠙ Bottle git (2.52.0_1)                #             Downloading 880.6KB/ 21.5MB⠚ Bottle libunistring (1.4.1)          #########     Downloading   1.3MB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              ####          Downloading   3.3MB/  9.6MB
# ⠚ Bottle pcre2 (10.47)                 ############  Downloading   2.3MB/  2.4MB
# ⠚ Bottle libiconv (1.18)               #########     Downloading   1.1MB/  1.6MB
# ⠚ Bottle git (2.52.0_1)                #             Downloading 946.2KB/ 21.5MB⠚ Bottle libunistring (1.4.1)          #########     Downloading   1.3MB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              #####         Downloading   3.4MB/  9.6MB
# ⠚ Bottle pcre2 (10.47)                 ############  Downloading   2.3MB/  2.4MB
# ⠚ Bottle libiconv (1.18)               #########     Downloading   1.1MB/  1.6MB
# ⠚ Bottle git (2.52.0_1)                #             Downloading 995.3KB/ 21.5MB⠞ Bottle libunistring (1.4.1)          #########     Downloading   1.3MB/  1.9MB
# ⠞ Bottle gettext (0.26_1)              #####         Downloading   3.4MB/  9.6MB
# ⠞ Bottle pcre2 (10.47)                 ############  Downloading   2.3MB/  2.4MB
# ⠞ Bottle libiconv (1.18)               ##########    Downloading   1.2MB/  1.6MB
# ⠞ Bottle git (2.52.0_1)                #             Downloading   1.1MB/ 21.5MB⠞ Bottle libunistring (1.4.1)          #########     Downloading   1.3MB/  1.9MB
# ⠞ Bottle gettext (0.26_1)              #####         Downloading   3.4MB/  9.6MB
# ⠞ Bottle pcre2 (10.47)                 ############  Downloading   2.3MB/  2.4MB
# ⠞ Bottle libiconv (1.18)               ##########    Downloading   1.2MB/  1.6MB
# ⠞ Bottle git (2.52.0_1)                #             Downloading   1.1MB/ 21.5MB⠖ Bottle libunistring (1.4.1)          #########     Downloading   1.3MB/  1.9MB
# ⠖ Bottle gettext (0.26_1)              #####         Downloading   3.4MB/  9.6MB
# ⠖ Bottle pcre2 (10.47)                 ############# Downloading   2.4MB/  2.4MB
# ⠖ Bottle libiconv (1.18)               ###########   Downloading   1.3MB/  1.6MB
# ⠖ Bottle git (2.52.0_1)                #             Downloading   1.1MB/ 21.5MB⠖ Bottle libunistring (1.4.1)          ##########    Downloading   1.4MB/  1.9MB
# ⠖ Bottle gettext (0.26_1)              #####         Downloading   3.5MB/  9.6MB
# ⠖ Bottle pcre2 (10.47)                 ############# Downloading   2.4MB/  2.4MB
# ⠖ Bottle libiconv (1.18)               ###########   Downloading   1.4MB/  1.6MB
# ⠖ Bottle git (2.52.0_1)                #             Downloading   1.2MB/ 21.5MB⠦ Bottle libunistring (1.4.1)          ##########    Downloading   1.4MB/  1.9MB
# ⠦ Bottle gettext (0.26_1)              #####         Downloading   3.5MB/  9.6MB
# ⠦ Bottle pcre2 (10.47)                               Extracting    2.4MB/  2.4MB
# ⠦ Bottle libiconv (1.18)               ############  Downloading   1.5MB/  1.6MB
# ⠦ Bottle git (2.52.0_1)                #             Downloading   1.3MB/ 21.5MB⠦ Bottle libunistring (1.4.1)          ##########    Downloading   1.4MB/  1.9MB
# ⠦ Bottle gettext (0.26_1)              #####         Downloading   3.5MB/  9.6MB
# ⠦ Bottle pcre2 (10.47)                               Extracting    2.4MB/  2.4MB
# ⠦ Bottle libiconv (1.18)               ############  Downloading   1.6MB/  1.6MB
# ⠦ Bottle git (2.52.0_1)                #             Downloading   1.3MB/ 21.5MB✔︎ Bottle pcre2 (10.47)                               Downloaded    2.4MB/  2.4MB
# ⠴ Bottle libunistring (1.4.1)          ##########    Downloading   1.5MB/  1.9MB
# ⠴ Bottle gettext (0.26_1)              #####         Downloading   3.6MB/  9.6MB
# ⠴ Bottle libiconv (1.18)                             Extracting    1.6MB/  1.6MB
# ⠴ Bottle git (2.52.0_1)                #             Downloading   1.4MB/ 21.5MB✔︎ Bottle libiconv (1.18)                             Downloaded    1.6MB/  1.6MB
# ⠴ Bottle libunistring (1.4.1)          ##########    Downloading   1.5MB/  1.9MB
# ⠴ Bottle gettext (0.26_1)              #####         Downloading   3.6MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                #             Downloading   1.4MB/ 21.5MB⠲ Bottle libunistring (1.4.1)          ###########   Downloading   1.6MB/  1.9MB
# ⠲ Bottle gettext (0.26_1)              #####         Downloading   3.6MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #             Downloading   1.5MB/ 21.5MB⠲ Bottle libunistring (1.4.1)          ###########   Downloading   1.6MB/  1.9MB
# ⠲ Bottle gettext (0.26_1)              #####         Downloading   3.7MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #             Downloading   1.5MB/ 21.5MB⠳ Bottle libunistring (1.4.1)          ###########   Downloading   1.6MB/  1.9MB
# ⠳ Bottle gettext (0.26_1)              #####         Downloading   3.7MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #             Downloading   1.5MB/ 21.5MB⠳ Bottle libunistring (1.4.1)          ###########   Downloading   1.6MB/  1.9MB
# ⠳ Bottle gettext (0.26_1)              #####         Downloading   3.7MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #             Downloading   1.5MB/ 21.5MB⠓ Bottle libunistring (1.4.1)          ###########   Downloading   1.6MB/  1.9MB
# ⠓ Bottle gettext (0.26_1)              #####         Downloading   3.7MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                #             Downloading   1.6MB/ 21.5MB⠓ Bottle libunistring (1.4.1)          ###########   Downloading   1.7MB/  1.9MB
# ⠓ Bottle gettext (0.26_1)              #####         Downloading   3.7MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                #             Downloading   1.6MB/ 21.5MB⠋ Bottle libunistring (1.4.1)          ############  Downloading   1.7MB/  1.9MB
# ⠋ Bottle gettext (0.26_1)              #####         Downloading   3.8MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                #             Downloading   1.6MB/ 21.5MB⠋ Bottle libunistring (1.4.1)          ############  Downloading   1.7MB/  1.9MB
# ⠋ Bottle gettext (0.26_1)              #####         Downloading   3.8MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                #             Downloading   1.7MB/ 21.5MB⠙ Bottle libunistring (1.4.1)          ############  Downloading   1.8MB/  1.9MB
# ⠙ Bottle gettext (0.26_1)              #####         Downloading   3.8MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                #             Downloading   1.7MB/ 21.5MB⠙ Bottle libunistring (1.4.1)          ############# Downloading   1.8MB/  1.9MB
# ⠙ Bottle gettext (0.26_1)              #####         Downloading   3.9MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                #             Downloading   1.7MB/ 21.5MB⠚ Bottle libunistring (1.4.1)          ############# Downloading   1.9MB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              #####         Downloading   3.9MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                #             Downloading   1.8MB/ 21.5MB⠚ Bottle libunistring (1.4.1)                        Extracting    1.9MB/  1.9MB
# ⠚ Bottle gettext (0.26_1)              #####         Downloading   3.9MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                #             Downloading   1.8MB/ 21.5MB✔︎ Bottle libunistring (1.4.1)                        Downloaded    1.9MB/  1.9MB
# ⠞ Bottle gettext (0.26_1)              #####         Downloading   3.9MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                #             Downloading   1.8MB/ 21.5MB⠞ Bottle gettext (0.26_1)              #####         Downloading   4.0MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                #             Downloading   1.9MB/ 21.5MB⠖ Bottle gettext (0.26_1)              #####         Downloading   4.0MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                #             Downloading   1.9MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ######        Downloading   4.1MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                #             Downloading   2.0MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ######        Downloading   4.1MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                #             Downloading   2.0MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ######        Downloading   4.1MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                #             Downloading   2.1MB/ 21.5MB⠴ Bottle gettext (0.26_1)              ######        Downloading   4.2MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                #             Downloading   2.1MB/ 21.5MB⠴ Bottle gettext (0.26_1)              ######        Downloading   4.2MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                #             Downloading   2.2MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #             Downloading   2.2MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #             Downloading   2.3MB/ 21.5MB⠳ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #             Downloading   2.3MB/ 21.5MB⠳ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #             Downloading   2.3MB/ 21.5MB⠓ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                #             Downloading   2.3MB/ 21.5MB⠓ Bottle gettext (0.26_1)              ######        Downloading   4.3MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                #             Downloading   2.3MB/ 21.5MB⠋ Bottle gettext (0.26_1)              ######        Downloading   4.4MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                #             Downloading   2.4MB/ 21.5MB⠋ Bottle gettext (0.26_1)              ######        Downloading   4.4MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                #             Downloading   2.4MB/ 21.5MB⠙ Bottle gettext (0.26_1)              ######        Downloading   4.5MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                #             Downloading   2.4MB/ 21.5MB⠙ Bottle gettext (0.26_1)              ######        Downloading   4.5MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                ##            Downloading   2.5MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ######        Downloading   4.5MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ##            Downloading   2.5MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ######        Downloading   4.6MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ##            Downloading   2.6MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ######        Downloading   4.6MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ##            Downloading   2.6MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ######        Downloading   4.6MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ##            Downloading   2.7MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ######        Downloading   4.7MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ##            Downloading   2.7MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ######        Downloading   4.7MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ##            Downloading   2.7MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ######        Downloading   4.8MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                ##            Downloading   2.8MB/ 21.5MB⠦ Bottle gettext (0.26_1)              #######       Downloading   4.8MB/  9.6MB
# ...
# ⠴ Bottle git (2.52.0_1)                ###           Downloading   4.1MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ########      Downloading   6.2MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                ###           Downloading   4.2MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ########      Downloading   6.3MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                ###           Downloading   4.3MB/ 21.5MB⠳ Bottle gettext (0.26_1)              #########     Downloading   6.3MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                ###           Downloading   4.4MB/ 21.5MB⠳ Bottle gettext (0.26_1)              #########     Downloading   6.4MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                ###           Downloading   4.5MB/ 21.5MB⠓ Bottle gettext (0.26_1)              #########     Downloading   6.5MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                ###           Downloading   4.6MB/ 21.5MB⠓ Bottle gettext (0.26_1)              #########     Downloading   6.6MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                ###           Downloading   4.7MB/ 21.5MB⠋ Bottle gettext (0.26_1)              #########     Downloading   6.7MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                ###           Downloading   4.8MB/ 21.5MB⠋ Bottle gettext (0.26_1)              #########     Downloading   6.8MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                ###           Downloading   4.8MB/ 21.5MB⠙ Bottle gettext (0.26_1)              #########     Downloading   6.8MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                ###           Downloading   4.9MB/ 21.5MB⠙ Bottle gettext (0.26_1)              #########     Downloading   6.9MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                ###           Downloading   5.0MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ##########    Downloading   7.0MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ###           Downloading   5.1MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ##########    Downloading   7.1MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ###           Downloading   5.2MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ##########    Downloading   7.2MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ###           Downloading   5.3MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ##########    Downloading   7.3MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ###           Downloading   5.4MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ##########    Downloading   7.4MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ###           Downloading   5.5MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ##########    Downloading   7.5MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ###           Downloading   5.6MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ##########    Downloading   7.6MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                ###           Downloading   5.7MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠴ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠴ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠲ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠳ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠳ Bottle gettext (0.26_1)              ##########    Downloading   7.7MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                ###           Downloading   5.8MB/ 21.5MB⠓ Bottle gettext (0.26_1)              ###########   Downloading   7.8MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                ####          Downloading   5.9MB/ 21.5MB⠓ Bottle gettext (0.26_1)              ###########   Downloading   7.8MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                ####          Downloading   5.9MB/ 21.5MB⠋ Bottle gettext (0.26_1)              ###########   Downloading   7.8MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                ####          Downloading   5.9MB/ 21.5MB⠋ Bottle gettext (0.26_1)              ###########   Downloading   7.9MB/  9.6MB
# ⠋ Bottle git (2.52.0_1)                ####          Downloading   6.0MB/ 21.5MB⠙ Bottle gettext (0.26_1)              ###########   Downloading   8.0MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                ####          Downloading   6.1MB/ 21.5MB⠙ Bottle gettext (0.26_1)              ###########   Downloading   8.1MB/  9.6MB
# ⠙ Bottle git (2.52.0_1)                ####          Downloading   6.2MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ###########   Downloading   8.2MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ####          Downloading   6.3MB/ 21.5MB⠚ Bottle gettext (0.26_1)              ###########   Downloading   8.3MB/  9.6MB
# ⠚ Bottle git (2.52.0_1)                ####          Downloading   6.4MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ###########   Downloading   8.5MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ####          Downloading   6.6MB/ 21.5MB⠞ Bottle gettext (0.26_1)              ############  Downloading   8.6MB/  9.6MB
# ⠞ Bottle git (2.52.0_1)                ####          Downloading   6.7MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ############  Downloading   8.8MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ####          Downloading   6.9MB/ 21.5MB⠖ Bottle gettext (0.26_1)              ############  Downloading   8.9MB/  9.6MB
# ⠖ Bottle git (2.52.0_1)                ####          Downloading   7.1MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ############  Downloading   9.2MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                ####          Downloading   7.3MB/ 21.5MB⠦ Bottle gettext (0.26_1)              ############# Downloading   9.3MB/  9.6MB
# ⠦ Bottle git (2.52.0_1)                #####         Downloading   7.5MB/ 21.5MB⠴ Bottle gettext (0.26_1)              ############# Downloading   9.5MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                #####         Downloading   7.6MB/ 21.5MB⠴ Bottle gettext (0.26_1)                            Extracting    9.6MB/  9.6MB
# ⠴ Bottle git (2.52.0_1)                #####         Downloading   7.9MB/ 21.5MB⠲ Bottle gettext (0.26_1)                            Extracting    9.6MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #####         Downloading   8.1MB/ 21.5MB⠲ Bottle gettext (0.26_1)                            Extracting    9.6MB/  9.6MB
# ⠲ Bottle git (2.52.0_1)                #####         Downloading   8.3MB/ 21.5MB⠳ Bottle gettext (0.26_1)                            Extracting    9.6MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #####         Downloading   8.4MB/ 21.5MB⠳ Bottle gettext (0.26_1)                            Extracting    9.6MB/  9.6MB
# ⠳ Bottle git (2.52.0_1)                #####         Downloading   8.5MB/ 21.5MB✔︎ Bottle gettext (0.26_1)                            Downloaded    9.6MB/  9.6MB
# ⠓ Bottle git (2.52.0_1)                #####         Downloading   8.5MB/ 21.5MB⠓ Bottle git (2.52.0_1)                #####         Downloading   8.7MB/ 21.5MB⠋ Bottle git (2.52.0_1)                #####         Downloading   8.9MB/ 21.5MB⠋ Bottle git (2.52.0_1)                #####         Downloading   9.0MB/ 21.5MB⠙ Bottle git (2.52.0_1)                ######        Downloading   9.1MB/ 21.5MB⠙ Bottle git (2.52.0_1)                ######        Downloading   9.2MB/ 21.5MB⠚ Bottle git (2.52.0_1)                ######        Downloading   9.4MB/ 21.5MB⠚ Bottle git (2.52.0_1)                ######        Downloading   9.4MB/ 21.5MB⠞ Bottle git (2.52.0_1)                ######        Downloading   9.5MB/ 21.5MB⠞ Bottle git (2.52.0_1)                ######        Downloading   9.6MB/ 21.5MB⠖ Bottle git (2.52.0_1)                ######        Downloading   9.7MB/ 21.5MB⠖ Bottle git (2.52.0_1)                ######        Downloading   9.8MB/ 21.5MB⠦ Bottle git (2.52.0_1)                ######        Downloading   9.9MB/ 21.5MB⠦ Bottle git (2.52.0_1)                ######        Downloading  10.0MB/ 21.5MB⠴ Bottle git (2.52.0_1)                ######        Downloading  10.1MB/ 21.5MB⠴ Bottle git (2.52.0_1)                ######        Downloading  10.2MB/ 21.5MB⠲ Bottle git (2.52.0_1)                ######        Downloading  10.3MB/ 21.5MB⠲ Bottle git (2.52.0_1)                ######        Downloading  10.4MB/ 21.5MB⠳ Bottle git (2.52.0_1)                ######        Downloading  10.5MB/ 21.5MB⠳ Bottle git (2.52.0_1)                ######        Downloading  10.6MB/ 21.5MB⠓ Bottle git (2.52.0_1)                ######        Downloading  10.7MB/ 21.5MB⠓ Bottle git (2.52.0_1)                #######       Downloading  10.8MB/ 21.5MB⠋ Bottle git (2.52.0_1)                #######       Downloading  11.0MB/ 21.5MB⠋ Bottle git (2.52.0_1)                #######       Downloading  11.1MB/ 21.5MB⠙ Bottle git (2.52.0_1)                #######       Downloading  11.2MB/ 21.5MB⠙ Bottle git (2.52.0_1)                #######       Downloading  11.3MB/ 21.5MB⠚ Bottle git (2.52.0_1)                #######       Downloading  11.4MB/ 21.5MB⠚ Bottle git (2.52.0_1)                #######       Downloading  11.6MB/ 21.5MB⠞ Bottle git (2.52.0_1)                #######       Downloading  11.7MB/ 21.5MB⠞ Bottle git (2.52.0_1)                #######       Downloading  11.8MB/ 21.5MB⠖ Bottle git (2.52.0_1)                #######       Downloading  12.0MB/ 21.5MB⠖ Bottle git (2.52.0_1)                #######       Downloading  12.1MB/ 21.5MB⠦ Bottle git (2.52.0_1)                #######       Downloading  12.2MB/ 21.5MB⠦ Bottle git (2.52.0_1)                #######       Downloading  12.4MB/ 21.5MB⠴ Bottle git (2.52.0_1)                ########      Downloading  12.5MB/ 21.5MB⠴ Bottle git (2.52.0_1)                ########      Downloading  12.5MB/ 21.5MB⠲ Bottle git (2.52.0_1)                ########      Downloading  12.5MB/ 21.5MB⠲ Bottle git (2.52.0_1)                ########      Downloading  12.5MB/ 21.5MB⠳ Bottle git (2.52.0_1)                ########      Downloading  12.5MB/ 21.5MB⠳ Bottle git (2.52.0_1)                ########      Downloading  12.6MB/ 21.5MB⠓ Bottle git (2.52.0_1)                ########      Downloading  12.7MB/ 21.5MB⠓ Bottle git (2.52.0_1)                ########      Downloading  12.9MB/ 21.5MB⠋ Bottle git (2.52.0_1)                ########      Downloading  13.0MB/ 21.5MB⠋ Bottle git (2.52.0_1)                ########      Downloading  13.2MB/ 21.5MB⠙ Bottle git (2.52.0_1)                ########      Downloading  13.3MB/ 21.5MB⠙ Bottle git (2.52.0_1)                ########      Downloading  13.4MB/ 21.5MB⠚ Bottle git (2.52.0_1)                ########      Downloading  13.6MB/ 21.5MB⠚ Bottle git (2.52.0_1)                ########      Downloading  13.7MB/ 21.5MB⠞ Bottle git (2.52.0_1)                ########      Downloading  13.9MB/ 21.5MB⠞ Bottle git (2.52.0_1)                ########      Downloading  14.0MB/ 21.5MB ...
# ==> Upgrading git
#   2.50.1 -> 2.52.0_1
# ==> Installing dependencies for git: libunistring, gettext, pcre2 and libiconv
# ==> Installing git dependency: libunistring
# ==> Pouring libunistring--1.4.1.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.4.1: 59 files, 5.8MB
# ==> Installing git dependency: gettext
# ==> Pouring gettext--0.26_1.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gettext/0.26_1: 2,428 files, 29.5MB
# ==> Installing git dependency: pcre2
# ==> Pouring pcre2--10.47.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pcre2/10.47: 244 files, 7.3MB
# ==> Installing git dependency: libiconv
# ==> Pouring libiconv--1.18.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libiconv/1.18: 32 files, 2.9MB
# ==> Installing git
# ==> Pouring git--2.52.0_1.arm64_tahoe.bottle.1.tar.gz
# ==> Caveats
# The Tcl/Tk GUIs (e.g. gitk, git-gui) are now in the `git-gui` formula.
# Subversion interoperability (git-svn) is now in the `git-svn` formula.
# ==> Summary
# 🍺  /opt/homebrew/Cellar/git/2.52.0_1: 1,733 files, 59.7MB
# ==> Running `brew cleanup git`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# Removing: /opt/homebrew/Cellar/git/2.50.1... (1,740 files, 58.6MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/git_bottle_manifest--2.50.1... (21.6KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/git--2.50.1... (21MB)
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# Removing: /Users/shivji/Library/Caches/Homebrew/gcc_bottle_manifest--15.1.0-1... (23.5KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gcc--15.1.0... (153.9MB)
# Removing: /opt/homebrew/Cellar/gettext/0.26... (2,428 files, 29.6MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gettext_bottle_manifest--0.26... (16KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gettext--0.26... (9.6MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gh_bottle_manifest--2.78.0... (7.3KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gh--2.78.0... (16.7MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gmp_bottle_manifest--6.3.0... (11.2KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/gmp--6.3.0... (1MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/isl_bottle_manifest--0.27... (12.2KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/isl--0.27... (1.7MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/libmpc_bottle_manifest--1.3.1... (14.2KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/libmpc--1.3.1... (147.5KB)
# Removing: /opt/homebrew/Cellar/libunistring/1.3... (59 files, 5.7MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/libunistring_bottle_manifest--1.3... (8.3KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/libunistring--1.3... (1.8MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/lz4_bottle_manifest--1.10.0-1... (11.6KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/lz4--1.10.0... (276.1KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/mpfr_bottle_manifest--4.2.2... (10.4KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/mpfr--4.2.2... (1MB)
# Removing: /opt/homebrew/Cellar/pcre2/10.45... (242 files, 7MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/pcre2_bottle_manifest--10.45... (10.5KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/pcre2--10.45... (2.3MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/xz_bottle_manifest--5.8.1... (11.8KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/xz--5.8.1... (748.1KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/zstd_bottle_manifest--1.5.7-1... (13.2KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/zstd--1.5.7... (788.5KB)
# Removing: /Users/shivji/Library/Caches/Homebrew/portable-ruby-3.4.8.arm64_big_sur.bottle.tar.gz... (12.2MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/portable-ruby-3.4.5.arm64_big_sur.bottle.tar.gz... (12.1MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/bootsnap/9857322932db1075c1bb0e18715c0100e54c980b13f0770aaa027620250b6c8c... (638 files, 5.5MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/bootsnap/c76bd5d607f544946a2f876e31b967af5b6ad99c68a2a67a0a02acc7c592f5f2... (623 files, 5.2MB)
# Removing: /Users/shivji/Library/Caches/Homebrew/bootsnap/496c245e5f804d12db27657fff8069a14912e240bd3b578d52fccd35c5909d8a... (637 files, 5.5MB)
# Removing: /Users/shivji/Library/Logs/Homebrew/gcc... (64B)
# ==> Caveats
# zsh completions and functions have been installed to:
#   /opt/homebrew/share/zsh/site-functions
# ==> git
# The Tcl/Tk GUIs (e.g. gitk, git-gui) are now in the `git-gui` formula.
# Subversion interoperability (git-svn) is now in the `git-svn` formula.

# %%
git -gui
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 git -gui
#
# NameError: name 'git' is not defined

# %%
# !git --version
# Out:
# git version 2.52.0

# %%
# !git config --global --list
# Out:
# user.name=ShivKumar207
# user.email=y.shiv@op.iitg.ac.in
# core.editor=code --wait

# %%
# !brew install git-gui
# Out:
# ⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠙ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠙ JSON API cask.jws.json                             Downloading  15.3MB/-------⠙ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠙ JSON API cask.jws.json                             Downloading  15.3MB/-------⠚ JSON API formula.jws.json                          Downloading 229.4KB/-------
# ⠚ JSON API cask.jws.json                             Downloading 262.1KB/-------⠚ JSON API formula.jws.json                          Downloading 643.1KB/-------
# ⠚ JSON API cask.jws.json                             Downloading 909.3KB/-------⠞ JSON API formula.jws.json                          Downloading 970.8KB/-------
# ⠞ JSON API cask.jws.json                             Downloading   1.8MB/-------⠞ JSON API formula.jws.json                          Downloading 970.8KB/-------
# ⠞ JSON API cask.jws.json                             Downloading   1.8MB/-------⠖ JSON API formula.jws.json                          Downloading   1.6MB/-------
# ⠖ JSON API cask.jws.json                             Downloading   2.4MB/-------⠖ JSON API formula.jws.json                          Downloading   2.5MB/-------
# ⠖ JSON API cask.jws.json                             Downloading   5.2MB/-------⠦ JSON API formula.jws.json                          Downloading   4.1MB/-------
# ⠦ JSON API cask.jws.json                             Downloading   8.9MB/-------⠦ JSON API formula.jws.json                          Downloading   7.6MB/-------
# ⠦ JSON API cask.jws.json                             Downloading  13.9MB/-------⠴ JSON API formula.jws.json                          Downloading  11.0MB/-------
# ⠴ JSON API cask.jws.json                             Downloading  15.3MB/-------⠴ JSON API formula.jws.json                          Downloading  12.7MB/-------
# ⠴ JSON API cask.jws.json                             Downloading  15.3MB/-------⠲ JSON API formula.jws.json                          Downloading  22.5MB/-------
# ✔︎ JSON API cask.jws.json                             Downloaded   15.3MB/ 15.3MB✔︎ JSON API cask.jws.json                             Downloaded   15.3MB/ 15.3MB
# ⠲ JSON API formula.jws.json                          Downloading  22.7MB/-------⠳ JSON API formula.jws.json                          Downloading  26.8MB/-------⠳ JSON API formula.jws.json                          Downloading  27.2MB/-------⠓ JSON API formula.jws.json                          Downloading  28.4MB/-------⠓ JSON API formula.jws.json                          Downloading  31.0MB/-------⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------✔︎ JSON API formula.jws.json                          Downloaded   32.0MB/ 32.0MB
# ==> Fetching downloads for: git-gui
# ⠋ Bottle Manifest git-gui (2.52.0)⠋ Bottle Manifest git-gui (2.52.0)⠙ Bottle Manifest git-gui (2.52.0)⠙ Bottle Manifest git-gui (2.52.0)⠚ Bottle Manifest git-gui (2.52.0)⠚ Bottle Manifest git-gui (2.52.0)⠞ Bottle Manifest git-gui (2.52.0)⠞ Bottle Manifest git-gui (2.52.0)⠖ Bottle Manifest git-gui (2.52.0)⠖ Bottle Manifest git-gui (2.52.0)⠦ Bottle Manifest git-gui (2.52.0)✔︎ Bottle Manifest git-gui (2.52.0)                   Downloaded    3.8KB/  3.8KB
# ⠴ Bottle Manifest libtommath (1.3.0)
# ⠴ Bottle libtommath (1.3.0)
# ⠴ Bottle Manifest ca-certificates (2025-12-02)
# ⠴ Bottle ca-certificates (2025-12-02)
# ⠴ Bottle Manifest openssl@3 (3.6.0)
# ⠴ Bottle openssl@3 (3.6.0)
# ⠴ Bottle Manifest tcl-tk (9.0.3)
# ⠴ Bottle tcl-tk (9.0.3)
# ⠴ Bottle git-gui (2.52.0)⠴ Bottle Manifest libtommath (1.3.0)
# ⠴ Bottle libtommath (1.3.0)
# ⠴ Bottle Manifest ca-certificates (2025-12-02)
# ⠴ Bottle ca-certificates (2025-12-02)
# ⠴ Bottle Manifest openssl@3 (3.6.0)
# ⠴ Bottle openssl@3 (3.6.0)
# ⠴ Bottle Manifest tcl-tk (9.0.3)
# ⠴ Bottle tcl-tk (9.0.3)
# ⠴ Bottle git-gui (2.52.0)⠲ Bottle Manifest libtommath (1.3.0)
# ⠲ Bottle libtommath (1.3.0)
# ⠲ Bottle Manifest ca-certificates (2025-12-02)
# ⠲ Bottle ca-certificates (2025-12-02)
# ⠲ Bottle Manifest openssl@3 (3.6.0)
# ⠲ Bottle openssl@3 (3.6.0)
# ⠲ Bottle Manifest tcl-tk (9.0.3)
# ⠲ Bottle tcl-tk (9.0.3)
# ⠲ Bottle git-gui (2.52.0)⠲ Bottle Manifest libtommath (1.3.0)
# ⠲ Bottle libtommath (1.3.0)
# ⠲ Bottle Manifest ca-certificates (2025-12-02)
# ⠲ Bottle ca-certificates (2025-12-02)
# ⠲ Bottle Manifest openssl@3 (3.6.0)
# ⠲ Bottle openssl@3 (3.6.0)
# ⠲ Bottle Manifest tcl-tk (9.0.3)
# ⠲ Bottle tcl-tk (9.0.3)
# ⠲ Bottle git-gui (2.52.0)⠳ Bottle Manifest libtommath (1.3.0)
# ⠳ Bottle libtommath (1.3.0)
# ⠳ Bottle Manifest ca-certificates (2025-12-02)
# ⠳ Bottle ca-certificates (2025-12-02)
# ⠳ Bottle Manifest openssl@3 (3.6.0)
# ⠳ Bottle openssl@3 (3.6.0)
# ⠳ Bottle Manifest tcl-tk (9.0.3)
# ⠳ Bottle tcl-tk (9.0.3)
# ⠳ Bottle git-gui (2.52.0)⠳ Bottle Manifest libtommath (1.3.0)
# ⠳ Bottle libtommath (1.3.0)
# ⠳ Bottle Manifest ca-certificates (2025-12-02)
# ⠳ Bottle ca-certificates (2025-12-02)
# ⠳ Bottle Manifest openssl@3 (3.6.0)
# ⠳ Bottle openssl@3 (3.6.0)
# ⠳ Bottle Manifest tcl-tk (9.0.3)
# ⠳ Bottle tcl-tk (9.0.3)
# ⠳ Bottle git-gui (2.52.0)⠓ Bottle Manifest libtommath (1.3.0)
# ⠓ Bottle libtommath (1.3.0)
# ⠓ Bottle Manifest ca-certificates (2025-12-02)
# ⠓ Bottle ca-certificates (2025-12-02)
# ⠓ Bottle Manifest openssl@3 (3.6.0)
# ⠓ Bottle openssl@3 (3.6.0)
# ⠓ Bottle Manifest tcl-tk (9.0.3)
# ⠓ Bottle tcl-tk (9.0.3)
# ⠓ Bottle git-gui (2.52.0)⠓ Bottle Manifest libtommath (1.3.0)
# ⠓ Bottle libtommath (1.3.0)
# ⠓ Bottle Manifest ca-certificates (2025-12-02)
# ⠓ Bottle ca-certificates (2025-12-02)
# ⠓ Bottle Manifest openssl@3 (3.6.0)
# ⠓ Bottle openssl@3 (3.6.0)
# ⠓ Bottle Manifest tcl-tk (9.0.3)
# ⠓ Bottle tcl-tk (9.0.3)
# ⠓ Bottle git-gui (2.52.0)⠋ Bottle Manifest libtommath (1.3.0)
# ⠋ Bottle libtommath (1.3.0)
# ⠋ Bottle Manifest ca-certificates (2025-12-02)
# ⠋ Bottle ca-certificates (2025-12-02)
# ⠋ Bottle Manifest openssl@3 (3.6.0)
# ⠋ Bottle openssl@3 (3.6.0)
# ⠋ Bottle Manifest tcl-tk (9.0.3)
# ⠋ Bottle tcl-tk (9.0.3)
# ⠋ Bottle git-gui (2.52.0)✔︎ Bottle Manifest libtommath (1.3.0)                 Downloaded   10.9KB/ 10.9KB
# ✔︎ Bottle Manifest ca-certificates (2025-12-02)       Downloaded    2.0KB/  2.0KB
# ⠋ Bottle libtommath (1.3.0)
# ⠋ Bottle ca-certificates (2025-12-02)
# ⠋ Bottle Manifest openssl@3 (3.6.0)
# ⠋ Bottle openssl@3 (3.6.0)
# ⠋ Bottle Manifest tcl-tk (9.0.3)
# ⠋ Bottle tcl-tk (9.0.3)
# ⠋ Bottle git-gui (2.52.0)✔︎ Bottle Manifest openssl@3 (3.6.0)                  Downloaded   11.8KB/ 11.8KB
# ⠙ Bottle libtommath (1.3.0)
# ⠙ Bottle ca-certificates (2025-12-02)
# ⠙ Bottle openssl@3 (3.6.0)
# ⠙ Bottle Manifest tcl-tk (9.0.3)
# ⠙ Bottle tcl-tk (9.0.3)
# ⠙ Bottle git-gui (2.52.0)✔︎ Bottle Manifest tcl-tk (9.0.3)                     Downloaded   13.9KB/ 13.9KB
# ⠙ Bottle libtommath (1.3.0)
# ⠙ Bottle ca-certificates (2025-12-02)
# ⠙ Bottle openssl@3 (3.6.0)
# ⠙ Bottle tcl-tk (9.0.3)
# ⠙ Bottle git-gui (2.52.0)⠚ Bottle libtommath (1.3.0)
# ⠚ Bottle ca-certificates (2025-12-02)          #     Downloading  32.8KB/131.8KB
# ⠚ Bottle openssl@3 (3.6.0)
# ⠚ Bottle tcl-tk (9.0.3)
# ⠚ Bottle git-gui (2.52.0)⠚ Bottle libtommath (1.3.0)
# ⠚ Bottle ca-certificates (2025-12-02)          ##### Downloading 131.8KB/131.8KB
# ⠚ Bottle openssl@3 (3.6.0)
# ⠚ Bottle tcl-tk (9.0.3)
# ⠚ Bottle git-gui (2.52.0)✔︎ Bottle ca-certificates (2025-12-02)                Downloaded  131.8KB/131.8KB
# ⠞ Bottle libtommath (1.3.0)
# ⠞ Bottle openssl@3 (3.6.0)
# ⠞ Bottle tcl-tk (9.0.3)
# ⠞ Bottle git-gui (2.52.0)⠞ Bottle libtommath (1.3.0)
# ⠞ Bottle openssl@3 (3.6.0)
# ⠞ Bottle tcl-tk (9.0.3)
# ⠞ Bottle git-gui (2.52.0)⠖ Bottle libtommath (1.3.0)
# ⠖ Bottle openssl@3 (3.6.0)
# ⠖ Bottle tcl-tk (9.0.3)
# ⠖ Bottle git-gui (2.52.0)⠖ Bottle libtommath (1.3.0)                    #     Downloading  32.8KB/149.1KB
# ⠖ Bottle openssl@3 (3.6.0)                           Downloading  32.8KB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)
# ⠖ Bottle git-gui (2.52.0)⠦ Bottle libtommath (1.3.0)                    ###   Downloading  94.2KB/149.1KB
# ⠦ Bottle openssl@3 (3.6.0)                           Downloading  94.2KB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                              Downloading  20.5KB/ 10.0MB
# ⠦ Bottle git-gui (2.52.0)                            Downloading  32.8KB/500.6KB⠦ Bottle libtommath (1.3.0)                          Extracting  149.1KB/149.1KB
# ⠦ Bottle openssl@3 (3.6.0)                           Downloading 225.3KB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                              Downloading  77.8KB/ 10.0MB
# ⠦ Bottle git-gui (2.52.0)                      #     Downloading  94.2KB/500.6KB✔︎ Bottle libtommath (1.3.0)                          Downloaded  149.1KB/149.1KB
# ⠴ Bottle openssl@3 (3.6.0)                           Downloading 536.6KB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                              Downloading 258.0KB/ 10.0MB
# ⠴ Bottle git-gui (2.52.0)                      ###   Downloading 274.4KB/500.6KB⠴ Bottle openssl@3 (3.6.0)                           Downloading 995.3KB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                              Downloading 454.7KB/ 10.0MB
# ⠴ Bottle git-gui (2.52.0)                            Extracting  500.6KB/500.6KB✔︎ Bottle git-gui (2.52.0)                            Downloaded  500.6KB/500.6KB
# ⠲ Bottle openssl@3 (3.6.0)                     #     Downloading   1.1MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                              Downloading 782.3KB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     #     Downloading   1.1MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                              Downloading 782.3KB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     #     Downloading   1.1MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                              Downloading 782.3KB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     #     Downloading   1.5MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                              Downloading 946.2KB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     #     Downloading   1.9MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        #     Downloading   1.2MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     #     Downloading   2.0MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        #     Downloading   1.3MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     #     Downloading   2.5MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        #     Downloading   1.4MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     #     Downloading   2.6MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        #     Downloading   1.5MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     #     Downloading   2.6MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        #     Downloading   1.6MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     #     Downloading   2.7MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        #     Downloading   1.7MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     #     Downloading   2.8MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        #     Downloading   2.1MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     #     Downloading   2.9MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        #     Downloading   2.4MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     #     Downloading   2.9MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        #     Downloading   2.4MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     #     Downloading   3.1MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        #     Downloading   2.7MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.3MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        #     Downloading   2.8MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.4MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        #     Downloading   2.9MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.4MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        #     Downloading   2.9MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.4MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        #     Downloading   3.0MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.7MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.1MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.8MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.2MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ##    Downloading   3.9MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.3MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.0MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.3MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.1MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.3MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.2MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.4MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.2MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.4MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.3MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.5MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.4MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.5MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.4MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.6MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.5MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.6MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.5MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.6MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.5MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.6MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.5MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.6MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.6MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.7MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.7MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.8MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.8MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.8MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ##    Downloading   4.9MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.9MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.0MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   3.9MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.0MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.0MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.1MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.0MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.2MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.1MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.3MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.1MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.3MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.2MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##    Downloading   5.4MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.3MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.5MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.3MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.5MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.3MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.5MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.3MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.5MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.3MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.5MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.6MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.6MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.6MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.6MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.6MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.4MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.7MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.5MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.7MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.5MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.8MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.6MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.9MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.6MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.9MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.6MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.9MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.6MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ###   Downloading   5.9MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.6MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.0MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.7MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.1MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.8MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.2MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.9MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.3MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   4.9MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.4MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ##    Downloading   5.0MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.5MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.1MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.5MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.1MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.6MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.2MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.7MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.3MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.8MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.4MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ###   Downloading   6.9MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.4MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.0MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.5MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.1MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.6MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.2MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.7MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.2MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.7MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.3MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.8MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.4MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ###   Downloading   5.9MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ###   Downloading   7.5MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.0MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ####  Downloading   7.7MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.1MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ####  Downloading   7.7MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.2MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ####  Downloading   7.8MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.2MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ####  Downloading   7.9MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.3MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.1MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.4MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.1MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.5MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.2MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.6MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.3MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.7MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.4MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.7MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.5MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.8MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.7MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ###   Downloading   6.9MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.7MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.0MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                     ####  Downloading   8.9MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.1MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.0MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.2MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.1MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.4MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.2MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.5MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.4MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.6MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.5MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.7MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.6MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.8MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ####  Downloading   9.7MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ####  Downloading   7.9MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                     ##### Downloading   9.9MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.0MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.0MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.1MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.1MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.2MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.1MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.2MB/ 10.0MB⠞ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.3MB/ 10.9MB
# ⠞ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.3MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.4MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.4MB/ 10.0MB⠖ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.5MB/ 10.9MB
# ⠖ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.6MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.6MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.7MB/ 10.0MB⠦ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.7MB/ 10.9MB
# ⠦ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.8MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                     ##### Downloading  10.9MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ####  Downloading   8.9MB/ 10.0MB⠴ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠴ Bottle tcl-tk (9.0.3)                        ####  Downloading   9.0MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.1MB/ 10.0MB⠲ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠲ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.3MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.4MB/ 10.0MB⠳ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠳ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.5MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.6MB/ 10.0MB⠓ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠓ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.8MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##### Downloading   9.9MB/ 10.0MB⠋ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠋ Bottle tcl-tk (9.0.3)                        ##### Downloading  10.0MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠙ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠙ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠚ Bottle openssl@3 (3.6.0)                           Extracting   10.9MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB✔︎ Bottle openssl@3 (3.6.0)                           Downloaded   10.9MB/ 10.9MB
# ⠚ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠞ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠞ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠖ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠖ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠦ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB⠦ Bottle tcl-tk (9.0.3)                              Extracting   10.0MB/ 10.0MB✔︎ Bottle tcl-tk (9.0.3)                              Downloaded   10.0MB/ 10.0MB
# ==> Installing dependencies for git-gui: libtommath, ca-certificates, openssl@3 and tcl-tk
# ==> Installing git-gui dependency: libtommath
# ==> Pouring libtommath--1.3.0.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtommath/1.3.0: 12 files, 525.5KB
# ==> Installing git-gui dependency: ca-certificates
# ==> Pouring ca-certificates--2025-12-02.all.bottle.1.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2025-12-02: 4 files, 236.4KB
# ==> Installing git-gui dependency: openssl@3
# ==> Pouring openssl@3--3.6.0.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openssl@3/3.6.0: 7,609 files, 37.7MB
# ==> Installing git-gui dependency: tcl-tk
# ==> Pouring tcl-tk--9.0.3.arm64_tahoe.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tcl-tk/9.0.3: 3,158 files, 40MB
# ==> Installing git-gui
# ==> Pouring git-gui--2.52.0.all.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/git-gui/2.52.0: 82 files, 2.3MB
# ==> Running `brew cleanup git-gui`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).

# %%
git --cersion
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 git --cersion
#
# NameError: name 'git' is not defined

# %%
git --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 git --version
#
# NameError: name 'git' is not defined

# %%
# !git --version
# Out:
# git version 2.52.0

# %%
# !git-gui --version
# Out:
# git-gui version 0.21.0.252.g7ef77e

# %%
# !git config --global --list
# Out:
# user.name=ShivKumar207
# user.email=y.shiv@op.iitg.ac.in
# core.editor=code --wait
